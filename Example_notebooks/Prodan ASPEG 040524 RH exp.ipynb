# %%
import sys
#change this to directory with flspectrum.py
sys.path.insert(1, "C:\\Users\\peo0005\\OneDrive - Auburn University\\Documents\\GitHub\\flProcessing")

import pandas as pd 
import matplotlib.pyplot as plt
import os
from scipy.signal import find_peaks, argrelmax
from scipy.signal import savgol_filter
from flspectrum import FlSpectrum

path = "C:\\Users\\peo0005\\OneDrive - Auburn University\\Desktop\\040524\\"

# %%
name = "PRO_ASPEG4_RH30_1.asc"
bgname = "PRO_ASPEG4_RH30_bg.asc"
RH = 30

#import data
tempspectrum = FlSpectrum(path,name,bgname,RH)

#smooth and subtract
smoothparam = 301
tempspectrum.bgSubtractAndSmooth(smoothparam)

#fit guassian
p0=[500.0,0.01,7000.0]
#tempspectrum.fitGuassian(p0)

#these are the two variables
print('smoothmax = ',tempspectrum.getSmoothMax())
print('gauss center = ', tempspectrum.getGaussCenter())


print('uncalibsmoothmax = ',tempspectrum.getSmoothMaxUncalib())
print('uncalibgausscenter = ', tempspectrum.getGaussCenterUncalib())

#NAME IT HERE
ProPEG_RH30_040524 = tempspectrum
# Out:
# FWHM=  75.35827
# smoothmax =  495.20163
# not gaussian fitted
# gauss center =  None
# not calibrated so no uncalibrated Gauss center
# uncalibsmoothmax =  None
# not calibrated or not gauss fitted so no uncalibrated Gauss center
# uncalibgausscenter =  None

# %%
name = "PRO_ASPEG4_RH30_2.asc"
bgname = "PRO_ASPEG4_RH30_bg.asc"
RH = 30

#import data
tempspectrum = FlSpectrum(path,name,bgname,RH)

#smooth and subtract
smoothparam = 301
tempspectrum.bgSubtractAndSmooth(smoothparam)

#fit guassian
p0=[500.0,0.01,7000.0]
#tempspectrum.fitGuassian(p0)

#these are the two variables
print('smoothmax = ',tempspectrum.getSmoothMax())
print('gauss center = ', tempspectrum.getGaussCenter())


print('uncalibsmoothmax = ',tempspectrum.getSmoothMaxUncalib())
print('uncalibgausscenter = ', tempspectrum.getGaussCenterUncalib())

#NAME IT HERE
ProPEG_RH302_040524 = tempspectrum
# Out:
# FWHM=  73.60900999999996
# smoothmax =  500.20392
# not gaussian fitted
# gauss center =  None
# not calibrated so no uncalibrated Gauss center
# uncalibsmoothmax =  None
# not calibrated or not gauss fitted so no uncalibrated Gauss center
# uncalibgausscenter =  None

# %%
name = "PRO_ASPEG_RH40_1.asc"
bgname = "PRO_ASPEG_RH40_bg.asc"
RH = 40

#import data
tempspectrum = FlSpectrum(path,name,bgname,RH)

#smooth and subtract
smoothparam = 301
tempspectrum.bgSubtractAndSmooth(smoothparam)

#fit guassian
p0=[500.0,0.01,7000.0]
#tempspectrum.fitGuassian(p0)

#these are the two variables
print('smoothmax = ',tempspectrum.getSmoothMax())
print('gauss center = ', tempspectrum.getGaussCenter())


print('uncalibsmoothmax = ',tempspectrum.getSmoothMaxUncalib())
print('uncalibgausscenter = ', tempspectrum.getGaussCenterUncalib())

#NAME IT HERE
ProPEG_RH40_040524 = tempspectrum
# Out:
# FWHM=  77.05385999999999
# smoothmax =  499.10977
# not gaussian fitted
# gauss center =  None
# not calibrated so no uncalibrated Gauss center
# uncalibsmoothmax =  None
# not calibrated or not gauss fitted so no uncalibrated Gauss center
# uncalibgausscenter =  None

# %%
name = "PRO_ASPEG_RH40_2.asc"
bgname = "PRO_ASPEG_RH40_bg.asc"
RH = 40

#import data
tempspectrum = FlSpectrum(path,name,bgname,RH)

#smooth and subtract
smoothparam = 301
tempspectrum.bgSubtractAndSmooth(smoothparam)

#fit guassian
p0=[500.0,0.01,7000.0]
#tempspectrum.fitGuassian(p0)

#these are the two variables
print('smoothmax = ',tempspectrum.getSmoothMax())
print('gauss center = ', tempspectrum.getGaussCenter())


print('uncalibsmoothmax = ',tempspectrum.getSmoothMaxUncalib())
print('uncalibgausscenter = ', tempspectrum.getGaussCenterUncalib())

#NAME IT HERE
ProPEG_RH402_040524 = tempspectrum
# Out:
# FWHM=  76.73775999999998
# smoothmax =  499.89133
# not gaussian fitted
# gauss center =  None
# not calibrated so no uncalibrated Gauss center
# uncalibsmoothmax =  None
# not calibrated or not gauss fitted so no uncalibrated Gauss center
# uncalibgausscenter =  None

# %%
name = "PRO_PEGAS_RH50_1.asc"
bgname = "PRO_PEGAS_RH50_bg.asc"
RH = 50

#import data
tempspectrum = FlSpectrum(path,name,bgname,RH)

#smooth and subtract
smoothparam = 301
tempspectrum.bgSubtractAndSmooth(smoothparam)

#fit guassian
p0=[500.0,0.01,7000.0]
#tempspectrum.fitGuassian(p0)

#these are the two variables
print('smoothmax = ',tempspectrum.getSmoothMax())
print('gauss center = ', tempspectrum.getGaussCenter())


print('uncalibsmoothmax = ',tempspectrum.getSmoothMaxUncalib())
print('uncalibgausscenter = ', tempspectrum.getGaussCenterUncalib())

#NAME IT HERE
ProPEG_RH50_040524 = tempspectrum
# Out:
# FWHM=  76.57886000000002
# smoothmax =  500.20392
# not gaussian fitted
# gauss center =  None
# not calibrated so no uncalibrated Gauss center
# uncalibsmoothmax =  None
# not calibrated or not gauss fitted so no uncalibrated Gauss center
# uncalibgausscenter =  None

# %%
name = "PRO_PEGAS_RH50_2.asc"
bgname = "PRO_PEGAS_RH50_bg.asc"
RH = 50

#import data
tempspectrum = FlSpectrum(path,name,bgname,RH)

#smooth and subtract
smoothparam = 301
tempspectrum.bgSubtractAndSmooth(smoothparam)

#fit guassian
p0=[500.0,0.01,7000.0]
#tempspectrum.fitGuassian(p0)

#these are the two variables
print('smoothmax = ',tempspectrum.getSmoothMax())
print('gauss center = ', tempspectrum.getGaussCenter())


print('uncalibsmoothmax = ',tempspectrum.getSmoothMaxUncalib())
print('uncalibgausscenter = ', tempspectrum.getGaussCenterUncalib())

#NAME IT HERE
ProPEG_RH502_040524 = tempspectrum
# Out:
# FWHM=  74.54775999999998
# smoothmax =  500.20392
# not gaussian fitted
# gauss center =  None
# not calibrated so no uncalibrated Gauss center
# uncalibsmoothmax =  None
# not calibrated or not gauss fitted so no uncalibrated Gauss center
# uncalibgausscenter =  None

# %%
name = "PRO_PEGAS2_RH50_1.asc"
bgname = "PRO_PEGAS2_RH50_bg.asc"
RH = 50

#import data
tempspectrum = FlSpectrum(path,name,bgname,RH)

#smooth and subtract
smoothparam = 301
tempspectrum.bgSubtractAndSmooth(smoothparam)

#fit guassian
p0=[500.0,0.01,7000.0]
#tempspectrum.fitGuassian(p0)

#these are the two variables
print('smoothmax = ',tempspectrum.getSmoothMax())
print('gauss center = ', tempspectrum.getGaussCenter())


print('uncalibsmoothmax = ',tempspectrum.getSmoothMaxUncalib())
print('uncalibgausscenter = ', tempspectrum.getGaussCenterUncalib())

#NAME IT HERE
ProPEG_RH503_040524 = tempspectrum
# Out:
# FWHM=  77.67534999999998
# smoothmax =  500.04764
# not gaussian fitted
# gauss center =  None
# not calibrated so no uncalibrated Gauss center
# uncalibsmoothmax =  None
# not calibrated or not gauss fitted so no uncalibrated Gauss center
# uncalibgausscenter =  None

# %%
name = "PRO_PEGAS2_RH50_2.asc"
bgname = "PRO_PEGAS2_RH50_bg.asc"
RH = 50

#import data
tempspectrum = FlSpectrum(path,name,bgname,RH)

#smooth and subtract
smoothparam = 301
tempspectrum.bgSubtractAndSmooth(smoothparam)

#fit guassian
p0=[500.0,0.01,7000.0]
#tempspectrum.fitGuassian(p0)

#these are the two variables
print('smoothmax = ',tempspectrum.getSmoothMax())
print('gauss center = ', tempspectrum.getGaussCenter())


print('uncalibsmoothmax = ',tempspectrum.getSmoothMaxUncalib())
print('uncalibgausscenter = ', tempspectrum.getGaussCenterUncalib())

#NAME IT HERE
ProPEG_RH504_040524 = tempspectrum
# Out:
# FWHM=  77.20627000000002
# smoothmax =  500.20392
# not gaussian fitted
# gauss center =  None
# not calibrated so no uncalibrated Gauss center
# uncalibsmoothmax =  None
# not calibrated or not gauss fitted so no uncalibrated Gauss center
# uncalibgausscenter =  None

# %%
name = "PRO_PEGAS_RH60_1.asc"
bgname = "PRO_PEGAS_RH60_bg.asc"
RH = 60

#import data
tempspectrum = FlSpectrum(path,name,bgname,RH)

#smooth and subtract
smoothparam = 301
tempspectrum.bgSubtractAndSmooth(smoothparam)

#fit guassian
p0=[500.0,0.01,7000.0]
#tempspectrum.fitGuassian(p0)

#these are the two variables
print('smoothmax = ',tempspectrum.getSmoothMax())
print('gauss center = ', tempspectrum.getGaussCenter())


print('uncalibsmoothmax = ',tempspectrum.getSmoothMaxUncalib())
print('uncalibgausscenter = ', tempspectrum.getGaussCenterUncalib())

#NAME IT HERE
ProPEG_RH60_040524 = tempspectrum
# Out:
# FWHM=  78.13479999999998
# smoothmax =  501.76691
# not gaussian fitted
# gauss center =  None
# not calibrated so no uncalibrated Gauss center
# uncalibsmoothmax =  None
# not calibrated or not gauss fitted so no uncalibrated Gauss center
# uncalibgausscenter =  None

# %%
name = "PRO_PEGAS_RH60_2.asc"
bgname = "PRO_PEGAS_RH60_bg.asc"
RH = 60

#import data
tempspectrum = FlSpectrum(path,name,bgname,RH)

#smooth and subtract
smoothparam = 301
tempspectrum.bgSubtractAndSmooth(smoothparam)

#fit guassian
p0=[500.0,0.01,7000.0]
#tempspectrum.fitGuassian(p0)

#these are the two variables
print('smoothmax = ',tempspectrum.getSmoothMax())
print('gauss center = ', tempspectrum.getGaussCenter())


print('uncalibsmoothmax = ',tempspectrum.getSmoothMaxUncalib())
print('uncalibgausscenter = ', tempspectrum.getGaussCenterUncalib())

#NAME IT HERE
ProPEG_RH602_040524 = tempspectrum
# Out:
# FWHM=  74.38831000000005
# smoothmax =  501.76691
# not gaussian fitted
# gauss center =  None
# not calibrated so no uncalibrated Gauss center
# uncalibsmoothmax =  None
# not calibrated or not gauss fitted so no uncalibrated Gauss center
# uncalibgausscenter =  None

# %%
name = "PRO_PEGAS_RH70_1.asc"
bgname = "PRO_PEGAS_RH70_bg.asc"
RH = 70

#import data
tempspectrum = FlSpectrum(path,name,bgname,RH)

#smooth and subtract
smoothparam = 301
tempspectrum.bgSubtractAndSmooth(smoothparam)

#fit guassian
p0=[500.0,0.01,7000.0]
#tempspectrum.fitGuassian(p0)

#these are the two variables
print('smoothmax = ',tempspectrum.getSmoothMax())
print('gauss center = ', tempspectrum.getGaussCenter())


print('uncalibsmoothmax = ',tempspectrum.getSmoothMaxUncalib())
print('uncalibgausscenter = ', tempspectrum.getGaussCenterUncalib())

#NAME IT HERE
ProPEG_RH70_040524 = tempspectrum
# Out:
# FWHM=  75.63367000000005
# smoothmax =  501.76691
# not gaussian fitted
# gauss center =  None
# not calibrated so no uncalibrated Gauss center
# uncalibsmoothmax =  None
# not calibrated or not gauss fitted so no uncalibrated Gauss center
# uncalibgausscenter =  None

# %%
name = "PRO_PEGAS_RH70_2.asc"
bgname = "PRO_PEGAS_RH70_bg.asc"
RH = 70

#import data
tempspectrum = FlSpectrum(path,name,bgname,RH)

#smooth and subtract
smoothparam = 301
tempspectrum.bgSubtractAndSmooth(smoothparam)

#fit guassian
p0=[500.0,0.01,7000.0]
#tempspectrum.fitGuassian(p0)

#these are the two variables
print('smoothmax = ',tempspectrum.getSmoothMax())
print('gauss center = ', tempspectrum.getGaussCenter())


print('uncalibsmoothmax = ',tempspectrum.getSmoothMaxUncalib())
print('uncalibgausscenter = ', tempspectrum.getGaussCenterUncalib())

#NAME IT HERE
ProPEG_RH702_040524 = tempspectrum
# Out:
# FWHM=  76.88242000000002
# smoothmax =  502.07947
# not gaussian fitted
# gauss center =  None
# not calibrated so no uncalibrated Gauss center
# uncalibsmoothmax =  None
# not calibrated or not gauss fitted so no uncalibrated Gauss center
# uncalibgausscenter =  None

# %%
name = "PRO_PEGAS_RH80_1.asc"
bgname = "PRO_PEGAS_RH80_bg.asc"
RH = 80

#import data
tempspectrum = FlSpectrum(path,name,bgname,RH)

#smooth and subtract
smoothparam = 301
tempspectrum.bgSubtractAndSmooth(smoothparam)

#fit guassian
p0=[500.0,0.01,7000.0]
#tempspectrum.fitGuassian(p0)

#these are the two variables
print('smoothmax = ',tempspectrum.getSmoothMax())
print('gauss center = ', tempspectrum.getGaussCenter())


print('uncalibsmoothmax = ',tempspectrum.getSmoothMaxUncalib())
print('uncalibgausscenter = ', tempspectrum.getGaussCenterUncalib())

#NAME IT HERE
ProPEG_RH80_040524 = tempspectrum
# Out:
# FWHM=  81.25393000000003
# smoothmax =  503.01718
# not gaussian fitted
# gauss center =  None
# not calibrated so no uncalibrated Gauss center
# uncalibsmoothmax =  None
# not calibrated or not gauss fitted so no uncalibrated Gauss center
# uncalibgausscenter =  None

# %%
name = "PRO_PEGAS_RH80_2.asc"
bgname = "PRO_PEGAS_RH80_bg.asc"
RH = 80

#import data
tempspectrum = FlSpectrum(path,name,bgname,RH)

#smooth and subtract
smoothparam = 301
tempspectrum.bgSubtractAndSmooth(smoothparam)

#fit guassian
p0=[500.0,0.01,7000.0]
#tempspectrum.fitGuassian(p0)

#these are the two variables
print('smoothmax = ',tempspectrum.getSmoothMax())
print('gauss center = ', tempspectrum.getGaussCenter())


print('uncalibsmoothmax = ',tempspectrum.getSmoothMaxUncalib())
print('uncalibgausscenter = ', tempspectrum.getGaussCenterUncalib())

#NAME IT HERE
ProPEG_RH802_040524 = tempspectrum
# Out:
# FWHM=  76.72528
# smoothmax =  501.76691
# not gaussian fitted
# gauss center =  None
# not calibrated so no uncalibrated Gauss center
# uncalibsmoothmax =  None
# not calibrated or not gauss fitted so no uncalibrated Gauss center
# uncalibgausscenter =  None

# %%
spectra = [ProPEG_RH802_040524, ProPEG_RH80_040524, ProPEG_RH702_040524, ProPEG_RH70_040524, ProPEG_RH602_040524, ProPEG_RH60_040524, ProPEG_RH302_040524, ProPEG_RH30_040524, ProPEG_RH402_040524, ProPEG_RH40_040524, ProPEG_RH502_040524, ProPEG_RH50_040524]
smoothmax = []
gausscenter = []
smoothmaxuncalib = []
gausscenteruncalib = []
RH = []
for spectrum in spectra:
    smoothmax.append(spectrum.getSmoothMax())
    #smoothmaxuncalib.append(spectrum.getSmoothMaxUncalib)
    RH.append(spectrum.RH)
    
plt.figure()
plt.title('Smooth Max Calib')
plt.scatter(RH, smoothmax)
plt.xlabel("Relative Humidity [%]")
plt.ylabel("Wavelength [nm]")
# Out:
# Text(0, 0.5, 'Wavelength [nm]')

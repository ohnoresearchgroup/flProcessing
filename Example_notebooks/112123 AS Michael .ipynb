# %%
import sys
#change this to directory with flspectrum.py
sys.path.insert(1, "C:\\Users\\amgib\\OneDrive\\Documents\\Flourescence Data")

import pandas as pd 
import matplotlib.pyplot as plt
import os
from scipy.signal import find_peaks, argrelmax
from scipy.signal import savgol_filter
from flspectrum import FlSpectrum

path ="C:\\Users\\amgib\\OneDrive\\Documents\\Raw Spectra Data\\2023\\112123\\AS\\"

# %%
name = "RH30.asc"
bgname = "BG30.asc"
RH = 30

#import data
tempspectrum = FlSpectrum(path,name,bgname,RH)

#calibrate x-axis, adjust prominence to be about half the difference between baseline and 532 peak
prominence = 2500
dataoffset = 0
bgoffset = 0

tempspectrum.calibrate(prominence,dataoffset,bgoffset)

#smooth and subtract
smoothparam = 301
tempspectrum.bgSubtractAndSmooth(smoothparam) 

#fit guassian
p0=[650.0,0.01,7000.0]
tempspectrum.fitGuassian(p0)

#these are the two variables
print(tempspectrum.smoothmax)
print(tempspectrum.gausscenter)

print(tempspectrum.smoothmaxuncalib)
print(tempspectrum.gausscenteruncalib)

#NAME IT HERE
AS_RH30_112123 = tempspectrum
# Out:
# bg shift  5.9456800000000385
# data shift  5.9456800000000385
# 624.93768
# 629.4696496260697
# 630.88336
# 635.4152777765328

# %%
name = "RH302.asc"
bgname = "BG30.asc"
RH = 30

#import data
tempspectrum = FlSpectrum(path,name,bgname,RH)

#calibrate x-axis, adjust prominence to be about half the difference between baseline and 532 peak
prominence = 2500
dataoffset = 0
bgoffset = 0

tempspectrum.calibrate(prominence,dataoffset,bgoffset)

#smooth and subtract
smoothparam = 301
tempspectrum.bgSubtractAndSmooth(smoothparam) 

#fit guassian
p0=[650.0,0.01,7000.0]
tempspectrum.fitGuassian(p0)

#these are the two variables
print(tempspectrum.smoothmax)
print(tempspectrum.gausscenter)

print(tempspectrum.smoothmaxuncalib)
print(tempspectrum.gausscenteruncalib)

#NAME IT HERE
AS_RH302_112123 = tempspectrum
# Out:
# bg shift  5.9456800000000385
# data shift  6.101679999999988
# 627.88617
# 629.9318859835523
# 633.98785
# 636.0335754560891

# %%
name = "RH40.asc"
bgname = "BG40.asc"
RH = 40

#import data
tempspectrum = FlSpectrum(path,name,bgname,RH)

#calibrate x-axis, adjust prominence to be about half the difference between baseline and 532 peak
prominence = 2500
dataoffset = 0
bgoffset = 0

tempspectrum.calibrate(prominence,dataoffset,bgoffset)

#smooth and subtract
smoothparam = 301
tempspectrum.bgSubtractAndSmooth(smoothparam) 

#fit guassian
p0=[650.0,0.01,7000.0]
tempspectrum.fitGuassian(p0)

#these are the two variables
print(tempspectrum.smoothmax)
print(tempspectrum.gausscenter)

print(tempspectrum.smoothmaxuncalib)
print(tempspectrum.gausscenteruncalib)

#NAME IT HERE
AS_RH40_112123 = tempspectrum
# Out:
# bg shift  6.257749999999987
# data shift  5.9456800000000385
# 636.4209599999999
# 636.512498366035
# 642.36664
# 642.4581773349199

# %%
name = "RH402.asc"
bgname = "BG40.asc"
RH = 40

#import data
tempspectrum = FlSpectrum(path,name,bgname,RH)

#calibrate x-axis, adjust prominence to be about half the difference between baseline and 532 peak
prominence = 2500
dataoffset = 0
bgoffset = 0

tempspectrum.calibrate(prominence,dataoffset,bgoffset)

#smooth and subtract
smoothparam = 301
tempspectrum.bgSubtractAndSmooth(smoothparam) 

#fit guassian
p0=[650.0,0.01,7000.0]
tempspectrum.fitGuassian(p0)

#these are the two variables
print(tempspectrum.smoothmax)
print(tempspectrum.gausscenter)

print(tempspectrum.smoothmaxuncalib)
print(tempspectrum.gausscenteruncalib)

#NAME IT HERE
AS_RH402_112123 = tempspectrum
# Out:
# bg shift  6.257749999999987
# data shift  5.477539999999976
# 637.19928
# 638.6660673243762
# 642.67682
# 644.1436004961694

# %%
name = "RH50.asc"
bgname = "BG50.asc"
RH = 50

#import data
tempspectrum = FlSpectrum(path,name,bgname,RH)

#calibrate x-axis, adjust prominence to be about half the difference between baseline and 532 peak
prominence = 2500
dataoffset = 0
bgoffset = 0

tempspectrum.calibrate(prominence,dataoffset,bgoffset)

#smooth and subtract
smoothparam = 301
tempspectrum.bgSubtractAndSmooth(smoothparam) 

#fit guassian
p0=[650.0,0.01,7000.0]
tempspectrum.fitGuassian(p0)

#these are the two variables
print(tempspectrum.smoothmax)
print(tempspectrum.gausscenter)

print(tempspectrum.smoothmaxuncalib)
print(tempspectrum.gausscenteruncalib)

#NAME IT HERE
AS_RH50_112123 = tempspectrum
# Out:
# bg shift  6.257749999999987
# data shift  5.633609999999976
# 638.59423
# 641.7523658125867
# 644.22784
# 647.3860027060434

# %%
name = "RH502.asc"
bgname = "BG50.asc"
RH = 50

#import data
tempspectrum = FlSpectrum(path,name,bgname,RH)

#calibrate x-axis, adjust prominence to be about half the difference between baseline and 532 peak
prominence = 2500
dataoffset = 0
bgoffset = 0

tempspectrum.calibrate(prominence,dataoffset,bgoffset)

#smooth and subtract
smoothparam = 301
tempspectrum.bgSubtractAndSmooth(smoothparam) 

#fit guassian
p0=[650.0,0.01,7000.0]
tempspectrum.fitGuassian(p0)

#these are the two variables
print(tempspectrum.smoothmax)
print(tempspectrum.gausscenter)

print(tempspectrum.smoothmaxuncalib)
print(tempspectrum.gausscenteruncalib)

#NAME IT HERE
AS_RH502_112123 = tempspectrum
# Out:
# bg shift  6.257749999999987
# data shift  5.633609999999976
# 638.74932
# 644.0854231205288
# 644.38293
# 649.7189944115471

# %%
name = "RH60.asc"
bgname = "BG60.asc"
RH = 60

#import data
tempspectrum = FlSpectrum(path,name,bgname,RH)

#calibrate x-axis, adjust prominence to be about half the difference between baseline and 532 peak
prominence = 2500
dataoffset = 0
bgoffset = 0

tempspectrum.calibrate(prominence,dataoffset,bgoffset)

#smooth and subtract
smoothparam = 301
tempspectrum.bgSubtractAndSmooth(smoothparam) 

#fit guassian
p0=[650.0,0.01,7000.0]
tempspectrum.fitGuassian(p0)

#these are the two variables
print(tempspectrum.smoothmax)
print(tempspectrum.gausscenter)

print(tempspectrum.smoothmaxuncalib)
print(tempspectrum.gausscenteruncalib)

#NAME IT HERE
AS_RH60_112123 = tempspectrum
# Out:
# bg shift  5.789610000000039
# data shift  5.789610000000039
# 639.0586
# 643.2631594938413
# 644.84821
# 649.0527680496272

# %%
name = "RH602.asc"
bgname = "BG60.asc"
RH = 60

#import data
tempspectrum = FlSpectrum(path,name,bgname,RH)

#calibrate x-axis, adjust prominence to be about half the difference between baseline and 532 peak
prominence = 2500
dataoffset = 0
bgoffset = 0

tempspectrum.calibrate(prominence,dataoffset,bgoffset)

#smooth and subtract
smoothparam = 301
tempspectrum.bgSubtractAndSmooth(smoothparam) 

#fit guassian
p0=[650.0,0.01,7000.0]
tempspectrum.fitGuassian(p0)

#these are the two variables
print(tempspectrum.smoothmax)
print(tempspectrum.gausscenter)

print(tempspectrum.smoothmaxuncalib)
print(tempspectrum.gausscenteruncalib)

#NAME IT HERE
AS_RH602_112123 = tempspectrum
# Out:
# bg shift  5.789610000000039
# data shift  6.101679999999988
# 640.76252
# 642.6837666011995
# 646.8642
# 648.7854097022436

# %%
name = "RH70.asc"
bgname = "BG70.asc"
RH = 70

#import data
tempspectrum = FlSpectrum(path,name,bgname,RH)

#calibrate x-axis, adjust prominence to be about half the difference between baseline and 532 peak
prominence = 2500
dataoffset = 0
bgoffset = 0

tempspectrum.calibrate(prominence,dataoffset,bgoffset)

#smooth and subtract
smoothparam = 301
tempspectrum.bgSubtractAndSmooth(smoothparam) 

#fit guassian
p0=[650.0,0.01,7000.0]
tempspectrum.fitGuassian(p0)

#these are the two variables
print(tempspectrum.smoothmax)
print(tempspectrum.gausscenter)

print(tempspectrum.smoothmaxuncalib)
print(tempspectrum.gausscenteruncalib)

#NAME IT HERE
AS_RH70_112123 = tempspectrum
# Out:
# bg shift  6.101679999999988
# data shift  5.9456800000000385
# 635.64532
# 641.9400881980267
# 641.591
# 647.8857787273176

# %%
name = "RH702.asc"
bgname = "BG70.asc"
RH = 70

#import data
tempspectrum = FlSpectrum(path,name,bgname,RH)

#calibrate x-axis, adjust prominence to be about half the difference between baseline and 532 peak
prominence = 2500
dataoffset = 0
bgoffset = 0

tempspectrum.calibrate(prominence,dataoffset,bgoffset)

#smooth and subtract
smoothparam = 301
tempspectrum.bgSubtractAndSmooth(smoothparam) 

#fit guassian
p0=[650.0,0.01,7000.0]
tempspectrum.fitGuassian(p0)

#these are the two variables
print(tempspectrum.smoothmax)
print(tempspectrum.gausscenter)

print(tempspectrum.smoothmaxuncalib)
print(tempspectrum.gausscenteruncalib)

#NAME IT HERE
AS_RH702_112123 = tempspectrum
# Out:
# bg shift  6.101679999999988
# data shift  6.257749999999987
# 638.43537
# 642.3472507078249
# 644.69312
# 648.6050105040019

# %%
name = "RH80.asc"
bgname = "BG80.asc"
RH = 80

#import data
tempspectrum = FlSpectrum(path,name,bgname,RH)

#calibrate x-axis, adjust prominence to be about half the difference between baseline and 532 peak
prominence = 2500
dataoffset = 0
bgoffset = 0

tempspectrum.calibrate(prominence,dataoffset,bgoffset)

#smooth and subtract
smoothparam = 301
tempspectrum.bgSubtractAndSmooth(smoothparam) 

#fit guassian
p0=[650.0,0.01,7000.0]
tempspectrum.fitGuassian(p0)

#these are the two variables
print(tempspectrum.smoothmax)
print(tempspectrum.gausscenter)

print(tempspectrum.smoothmaxuncalib)
print(tempspectrum.gausscenteruncalib)

#NAME IT HERE
AS_RH80_112123 = tempspectrum
# Out:
# bg shift  6.101679999999988
# data shift  6.101679999999988
# 638.74653
# 640.6127641631153
# 644.84821
# 646.7145263508845

# %%
name = "RH802.asc"
bgname = "BG80.asc"
RH = 80

#import data
tempspectrum = FlSpectrum(path,name,bgname,RH)

#calibrate x-axis, adjust prominence to be about half the difference between baseline and 532 peak
prominence = 2500
dataoffset = 0
bgoffset = 0

tempspectrum.calibrate(prominence,dataoffset,bgoffset)

#smooth and subtract
smoothparam = 301
tempspectrum.bgSubtractAndSmooth(smoothparam) 

#fit guassian
p0=[650.0,0.01,7000.0]
tempspectrum.fitGuassian(p0)

#these are the two variables
print(tempspectrum.smoothmax)
print(tempspectrum.gausscenter)

print(tempspectrum.smoothmaxuncalib)
print(tempspectrum.gausscenteruncalib)

#NAME IT HERE
AS_RH802_112123 = tempspectrum
# Out:
# bg shift  6.101679999999988
# data shift  5.789610000000039
# 639.2136899999999
# 641.6409570596459
# 645.0033
# 647.4305662652797

# %%
#####add each named spectrumobject here#######
spectra = [AS_RH802_112123, AS_RH80_112123, AS_RH702_112123, AS_RH70_112123, AS_RH602_112123, AS_RH60_112123, AS_RH502_112123, AS_RH50_112123, AS_RH402_112123, AS_RH40_112123, AS_RH302_112123, AS_RH30_112123]

smoothmax = []
gausscenter = []
smoothmaxuncalib = []
gausscenteruncalib = []
RH = []
for spectrum in spectra:
    smoothmax.append(spectrum.smoothmax)
    gausscenter.append(spectrum.gausscenter)
    smoothmaxuncalib.append(spectrum.smoothmaxuncalib)
    gausscenteruncalib.append(spectrum.gausscenteruncalib)
    RH.append(spectrum.RH)

# %%
plt.figure()
plt.title('Smooth Max Calib')
plt.scatter(RH, smoothmax)
plt.xlabel("Relative Humidity [%]")
plt.ylabel("Wavelength [nm]")
# Out:
# Text(0, 0.5, 'Wavelength [nm]')
